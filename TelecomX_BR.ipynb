# %% [markdown]
# <a href="https://colab.research.google.com/github/Jesuan333/Challenge-TELECOM-X---ORACLE-ONE/blob/main/TelecomX_BR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


url = 'https://raw.githubusercontent.com/ingridcristh/challenge2-data-science/refs/heads/main/TelecomX_Data.json'

# %% [markdown]
# #📔Dicionário de dados

# %% [markdown]
# *customerID*: número de identificação único de cada cliente
#
# *Churn*: se o cliente deixou ou não a empresa
#
# *gender*: gênero (masculino e feminino)
#
# *SeniorCitizen*: informação sobre um cliente ter ou não idade igual ou maior que 65 anos
#
# *Partner*: se o cliente possui ou não um parceiro ou parceira
#
# *Dependents*: se o cliente possui ou não dependentes
# tenure: meses de contrato do cliente
#
# *PhoneService*: assinatura de serviço telefônico
#
# *MultipleLines*: assisnatura de mais de uma linha de telefone
#
# *InternetService*: assinatura de um provedor internet
#
# *OnlineSecurity*: assinatura adicional de segurança online
#
# *OnlineBackup*: assinatura adicional de backup online
#
# *DeviceProtection*: assinatura adicional de proteção no dispositivo
#
# *TechSupport*: assinatura adicional de suporte técnico, menos tempo de espera
#
# *StreamingTV*: assinatura de TV a cabo
#
# *StreamingMovies*: assinatura de streaming de filmes
#
# *Contract*: tipo de contrato
#
# *PaperlessBilling*: se o cliente prefere receber online a fatura
#
# *PaymentMethod*: forma de pagamento
#
# *Charges.Monthly*: total de todos os serviços do cliente por mês
#
# *Charges.Total*: total gasto pelo cliente

# %% [markdown]
# #📌 Extracão

# %%
dados = pd.read_json(url)
dados
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# ...

# %%
dados.shape # linhas e colunas
# Out:
# (7267, 6)

# %%
dados.info() # tipos de daodos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %%
dados.describe()
# Out:
#         customerID Churn                                           customer  \
# count         7267  7267                                               7267
# unique        7267     3                                                891
# top     9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# freq             1  5174                                                223
#
#                                                  phone  \
# count                                             7267
# unique                                               3
# top     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# freq                                              3495
#
#                                                  internet  \
# count                                                7267
# unique                                                129
# top     {'InternetService': 'No', 'OnlineSecurity': 'N...
# freq                                                 1581
#
# ...

# %% [markdown]
# #🔧 Transformação

# %%
dados.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
# Normalize nested 'customer' column
df_customer = pd.json_normalize(dados['customer'])

# Normalize nested 'phone' column
df_phone = pd.json_normalize(dados['phone'])

# Normalize nested 'internet' column
df_internet = pd.json_normalize(dados['internet'])

# Normalize nested 'account' column
df_account = pd.json_normalize(dados['account'])
# Select the already flat columns
df_flat_main = dados[['customerID', 'Churn']]

# Concatenate all normalized parts along with the original flat columns
dados = pd.concat([df_flat_main, df_customer, df_phone, df_internet, df_account], axis=1)

dados['Churn'] = dados['Churn'].replace("", "No data")

# %% [markdown]
# #📊 Carga e análise

# %%
#média de cobranças por mês, máximo e mínimo cobrado por mês

# Convert 'Charges.Monthly' and 'Charges.Total' to numeric, coercing errors to NaN
dados['Charges.Monthly'] = pd.to_numeric(dados['Charges.Monthly'], errors='coerce')
dados['Charges.Total'] = pd.to_numeric(dados['Charges.Total'], errors='coerce')

# Fill NaN values with 0. This assumes that missing charges should be treated as zero.
dados['Charges.Monthly'] = dados['Charges.Monthly'].fillna(0)
dados['Charges.Total'] = dados['Charges.Total'].fillna(0)

média_cobrança_mes = dados['Charges.Monthly'].mean()
média_cobrança_total = dados['Charges.Total'].mean()
max_cobrança_mes = dados['Charges.Monthly'].max()
min_cobrança_mes = dados['Charges.Monthly'].min()

print('O preço médio cobrado por cliente foi de ', média_cobrança_mes, ' Dólares.')
print('O preço médio cobrado por cliente no total foi de ', média_cobrança_total, ' Dólares.')
print('O máximo cobrado para um cliente foi ', max_cobrança_mes, ' Dólares.')
print('O mínimo cobrado para um cliente foi ', min_cobrança_mes, ' Dólares.')
# Out:
# O preço médio cobrado por cliente foi de  64.72009770194028  Dólares.
# O preço médio cobrado por cliente no total foi de  2277.182035227742  Dólares.
# O máximo cobrado para um cliente foi  118.75  Dólares.
# O mínimo cobrado para um cliente foi  18.25  Dólares.

# %%
# Clientes que foram cobrados acima da média ao mês
clientes_acima_media_mes = dados[dados['Charges.Monthly'] > média_cobrança_mes]
clientes_acima_media_mes
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     0002-ORFBO    No  Female              0     Yes        Yes       9
# 2     0004-TLHLJ   Yes    Male              0      No         No       4
# 3     0011-IGKFF   Yes    Male              1     Yes         No      13
# 4     0013-EXCHZ   Yes  Female              1     Yes         No       3
# 5     0013-MHZWF    No  Female              0      No        Yes       9
# ...          ...   ...     ...            ...     ...        ...     ...
# 7258  9978-HYCIN    No    Male              1     Yes        Yes      47
# 7259  9979-RGMZT    No  Female              0      No         No       7
# 7260  9985-MWVIX   Yes  Female              0      No         No       1
# 7263  9992-RRAMN   Yes    Male              0     Yes         No      22
# 7265  9993-LHIEB    No    Male              0     Yes        Yes      67
#
#      PhoneService MultipleLines InternetService  ... OnlineBackup  \
# ...

# %%
# Clientes que foram cobrados acima da média do total
clientes_acima_media_total = dados[dados['Charges.Total'] > média_cobrança_total]
clientes_acima_media_total
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 6     0013-SMEOE    No  Female              1     Yes         No      71
# 7     0014-BMAQU    No    Male              0     Yes         No      63
# 9     0016-QLJIS    No  Female              0     Yes        Yes      65
# 10    0017-DINOC    No    Male              0      No         No      54
# 11    0017-IUDMW    No  Female              0     Yes        Yes      72
# ...          ...   ...     ...            ...     ...        ...     ...
# 7254  9972-VAFJJ    No  Female              1     Yes         No      53
# 7255  9974-JFBHQ    No    Male              0      No        Yes      64
# 7258  9978-HYCIN    No    Male              1     Yes        Yes      47
# 7265  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7266  9995-HOTOH    No    Male              0     Yes        Yes      63
#
#      PhoneService     MultipleLines InternetService  ... OnlineBackup  \
# ...

# %%
# Valor mediano de pagamentos por gênero ao mês
valor_mediano_mes = dados.groupby("gender")["Charges.Monthly"].median()
valor_mediano_mes
# Out:
# gender
# Female    70.55
# Male      70.05
# Name: Charges.Monthly, dtype: float64

# %%
# Valor mediano de pagamentos por gênero no total
valor_mediano_total = dados.groupby("gender")["Charges.Total"].median()
valor_mediano_total
# Out:
# gender
# Female    1378.50
# Male      1399.35
# Name: Charges.Total, dtype: float64

# %%
desvio_cobrado_mes = dados["Charges.Monthly"].std()
desvio_cobrado_total = dados["Charges.Total"].std()

print('O desvio de Valores cobrados ao mês foi de: ', desvio_cobrado_mes)
print('O desvio de Valores cobrados no total foi de: ', desvio_cobrado_total)
# Out:
# O desvio de Valores cobrados ao mês foi de:  30.12957188566699
# O desvio de Valores cobrados no total foi de:  2268.648586624864

# %%
desvio_cobrado_mes_gênero = dados.groupby("gender")["Charges.Monthly"].std()
desvio_cobrado_total_gênero = dados.groupby("gender")["Charges.Total"].std()

print('O desvio de Valores cobrados ao mês, por gênero, foi de: ', desvio_cobrado_mes_gênero)
print('O desvio de Valores cobrados no total, por gênero, foi de: ', desvio_cobrado_total_gênero)
# Out:
# O desvio de Valores cobrados ao mês, por gênero, foi de:  gender
# Female    30.112419
# Male      30.144682
# Name: Charges.Monthly, dtype: float64
# O desvio de Valores cobrados no total, por gênero, foi de:  gender
# Female    2274.758957
# Male      2262.969548
# Name: Charges.Total, dtype: float64

# %% [markdown]
# # Avaliando Churn

# %%
estudo_churn = dados[['customerID', 'Churn', 'InternetService', 'Contract', 'Charges.Total']]
estudo_churn
# Out:
#       customerID Churn InternetService        Contract Charges.Total
# 0     0002-ORFBO    No             DSL        One year         593.3
# 1     0003-MKNFE    No             DSL  Month-to-month         542.4
# 2     0004-TLHLJ   Yes     Fiber optic  Month-to-month        280.85
# 3     0011-IGKFF   Yes     Fiber optic  Month-to-month       1237.85
# 4     0013-EXCHZ   Yes     Fiber optic  Month-to-month         267.4
# ...          ...   ...             ...             ...           ...
# 7262  9987-LUTYD    No             DSL        One year         742.9
# 7263  9992-RRAMN   Yes     Fiber optic  Month-to-month        1873.7
# 7264  9992-UJOEL    No             DSL  Month-to-month         92.75
# 7265  9993-LHIEB    No             DSL        Two year       4627.65
# 7266  9995-HOTOH    No             DSL        Two year        3707.6
#
# [7267 rows x 5 columns]

# %% [markdown]
# # Estudo de evasão

# %%
taxa_churn = (dados["Churn"].value_counts(normalize=True).fillna(0) * 100).round(2)

labels = ['No', 'Yes', 'No data']

plt.figure(figsize=(9,11))

plt.pie(taxa_churn, labels=labels, autopct='%1.2f%%', startangle=90)
plt.title("Taxa de Churn")
plt.axis('equal')


plt.legend(labels, title="Churn", loc="center left")

plt.show()

# %%
contrato_churn = estudo_churn.groupby(["Contract", "Churn"]).size().unstack()

ax = contrato_churn.plot(kind="bar", stacked=True, figsize=(8, 6))

plt.title("Churn por Tipo de Contrato")
plt.xlabel("Tipo de Contrato")
plt.ylabel("Número de Clientes")
plt.xticks(rotation=0)
ax.legend(title="Churn") # Adiciona a legenda usando o objeto Axes (ax)

plt.show()

# %%
dados.head(2)
# Out:
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female              0     Yes        Yes       9
# 1  0003-MKNFE    No    Male              0      No         No       9
#
#   PhoneService MultipleLines InternetService  ... OnlineBackup  \
# 0          Yes            No             DSL  ...          Yes
# 1          Yes           Yes             DSL  ...           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No         Yes         Yes              No        One year
# 1               No          No          No             Yes  Month-to-month
#
#   PaperlessBilling PaymentMethod Charges.Monthly  Charges.Total
# 0              Yes  Mailed check            65.6          593.3
# 1               No  Mailed check            59.9          542.4
#
# [2 rows x 21 columns]

# %%
cliente_perfil_evasao = dados[dados['Churn'] == 'No'][['customerID', 'Churn', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV','StreamingMovies']]

dados['PhoneService'] = dados['PhoneService'].replace({'No': 'Not applied'})
dados['PhoneService']
cliente_evasao_PhoneService = cliente_perfil_evasao['PhoneService'].value_counts()

dados['MultipleLines'] = dados['MultipleLines'].replace({'No': 'Not applied'})
dados['MultipleLines']
cliente_evasao_MultipleLines  = cliente_perfil_evasao['MultipleLines'].value_counts()

dados['InternetService'] = dados['InternetService'].replace({'No': 'Not applied'})
dados['InternetService']
cliente_evasao_InternetService  = cliente_perfil_evasao['InternetService'].value_counts()


dados['OnlineBackup'] = dados['OnlineBackup'].replace({'No': 'Not applied'})
dados['OnlineBackup']
cliente_evasao_OnlineBackup  = cliente_perfil_evasao['OnlineBackup'].value_counts()


dados['DeviceProtection'] = dados['DeviceProtection'].replace({'No': 'Not applied'})
dados['DeviceProtection']
cliente_evasao_DeviceProtection  = cliente_perfil_evasao['DeviceProtection'].value_counts()

dados['TechSupport'] = dados['TechSupport'].replace({'No': 'Not applied'})
dados['TechSupport']
cliente_evasao_TechSupport  = cliente_perfil_evasao['TechSupport'].value_counts()


dados['StreamingTV'] = dados['StreamingTV'].replace({'No': 'Not applied'})
dados['StreamingTV']
cliente_evasao_StreamingTV  = cliente_perfil_evasao['StreamingTV'].value_counts()


dados['StreamingMovies'] = dados['StreamingMovies'].replace({'No': 'Not applied'})
dados['StreamingMovies']
cliente_evasao_StreamingMovies  = cliente_perfil_evasao['StreamingMovies'].value_counts()

# %%
plt.figure(figsize=(6, 4))
plt.bar(cliente_evasao_PhoneService.index, cliente_evasao_PhoneService.values, color=['skyblue', 'lightcoral'])
plt.title('Distribuição de clientes sem churn por uso do Phone Service')
plt.xlabel('Phone Service')
plt.ylabel('Número de Clientes')
plt.show()

# %%
plt.figure(figsize=(6, 4))
plt.bar(cliente_evasao_MultipleLines.index, cliente_evasao_MultipleLines.values, color=['skyblue', 'lightcoral'])
plt.title('Distribuição de clientes sem churn por uso do MultipleLines')
plt.xlabel('Multiple Lines')
plt.ylabel('Número de Clientes')
plt.show()

# %%
plt.figure(figsize=(6, 4))
plt.bar(cliente_evasao_InternetService.index, cliente_evasao_InternetService.values, color=['skyblue', 'lightcoral'])
plt.title('Distribuição de clientes sem churn por uso do Internet Service')
plt.xlabel('Internet Service')
plt.ylabel('Número de Clientes')
plt.show()

# %%
plt.figure(figsize=(6, 4))
plt.bar(cliente_evasao_OnlineBackup.index, cliente_evasao_OnlineBackup.values, color=['skyblue', 'lightcoral'])
plt.title('Distribuição de clientes sem churn por uso do Online Backup')
plt.xlabel('Online Backup')
plt.ylabel('Número de Clientes')
plt.show()

# %%
plt.figure(figsize=(6, 4))
plt.bar(cliente_evasao_DeviceProtection.index, cliente_evasao_DeviceProtection.values, color=['skyblue', 'lightcoral'])
plt.title('Distribuição de clientes sem churn por uso do Device Protection')
plt.xlabel('Device Protection')
plt.ylabel('Número de Clientes')
plt.show()

# %%
plt.figure(figsize=(6, 4))
plt.bar(cliente_evasao_TechSupport.index, cliente_evasao_TechSupport.values, color=['skyblue', 'lightcoral'])
plt.title('Distribuição de clientes sem churn por uso do Tech Support')
plt.xlabel('Tech Support')
plt.ylabel('Número de Clientes')
plt.show()

# %%
plt.figure(figsize=(6, 4))
plt.bar(cliente_evasao_StreamingTV.index, cliente_evasao_StreamingTV.values, color=['skyblue', 'lightcoral'])
plt.title('Distribuição de clientes sem churn por uso do Streaming TV')
plt.xlabel('Streaming TV')
plt.ylabel('Número de Clientes')
plt.show()

# %%
plt.figure(figsize=(6, 4))
plt.bar(cliente_evasao_StreamingMovies.index, cliente_evasao_StreamingMovies.values, color=['skyblue', 'lightcoral'])
plt.title('Distribuição de clientes sem churn por uso do Streaming Movies')
plt.xlabel('Streaming Movies')
plt.ylabel('Número de Clientes')
plt.show()

# %% [markdown]
# #📄Relatorio Final
